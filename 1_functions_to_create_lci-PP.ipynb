# %% [markdown]
# # Setup

# %%
import pandas as pd
import copy
import numpy as np
import warnings
import math

from pprint import pformat
import xlsxwriter
import os
import json
import pprint
from datetime import datetime

# %% [markdown]
# # Functions

# %% [markdown]
# ## Import

# %% [markdown]
# <div class="alert alert-info">
#
# Funktionen, die benötigt werden, um Input-Exceldatei auszulesen und die notwendigen excel-sheets als panda-dataframe im dictionary-Format zurückzugeben.

# %%
def read_excel_file(filepath, sheet_names):
    print("Apply strategies: read excel-file ...")
    xl = pd.ExcelFile(filepath)
    dfs = {sheet_name: xl.parse(sheet_name).T.to_dict() for sheet_name in sheet_names}
    
    return tuple(dfs.values())

# %%
def unzip_dict(df):
    df_new = [df[a] for a in df]
    return df_new

# %% [markdown]
# # Transformation & Calculation Functions

# %% [markdown]
# ## D_PSE (,U_PSE)

# %%
def add_träger_column(df):
    print("Apply strategies - PP: add täger-column ...")
    for a in df:
        #lowest_e = True if a+1 in df and df[a+1]["Ebene"]<= df[a]["Ebene"] else False
        current_e=a["Ebene"]
        current_nr=a["Nr."]
        e0, e1, e2, e3, e4 = (
            current_nr if current_e == 0 else e0 if current_e >= 0 else "-", 
            current_nr if current_e == 1 else e1 if current_e >= 1 else "-",
            current_nr if current_e == 2 else e2 if current_e >= 2 else "-",
            current_nr if current_e == 3 else e3 if current_e >= 3 else "-",
            current_nr if current_e == 4 else "-"
        )
        upper_e = (
            e3 if current_e == 4
            else e2 if current_e == 3
            else e1 if current_e == 2
            else e0 if current_e == 1
            else "-"
        )
        a["Träger"]=upper_e
    
    return df

# %%
def transform_excel_sheet_to_matrix(df):
    print("Apply strategies - PP: transform excel-sheet to D_PSE matrix ...")
    df_new = []
    for a_count, PSE_a in enumerate(df):
        df_new.append({
            "name":PSE_a['Bezeichnung'],
            "reference product":PSE_a['Bezeichnung'],
            "unit":"pcs.",
            "code":PSE_a['Nr.'],
            "level":PSE_a['Ebene'],
            "exchanges":[{
                "name":PSE_a['Bezeichnung'],
                "reference product":PSE_a['Bezeichnung'],
                "unit":"pcs.",
                "code":PSE_a['Nr.'],
                "type":"production",
                "amount":1
            }]
        })
        for a2 in df:
            if a2['Träger']==df_new[a_count]["code"]:
                df_new[a_count]["exchanges"].append({
                    "name":a2['Bezeichnung'],
                    "reference product":a2['Bezeichnung'],
                    "unit":"pcs.",
                    "code":a2['Nr.'],
                    "type":"technosphere",
                    "amount":-a2['Menge']
                })
    
    return df_new

# %%
def sort_column_by_level(matrix):
    print("Apply strategies - PP: sort matrix-column by level (descending) ...")
    
    matrix_new=sorted(matrix, key=lambda d: d['level'])
    
    return matrix_new

# %% [markdown]
# ## D_PPZ, U_PPZ

# %% [markdown]
# <div class="alert alert-info">
#
# ``read_excel_file(filepath, sheet_names)`` ausführen und "4-Prozesse"-Tabelle auswählen

# %%
def filter_out_PPZ_PZ_old(df):
    print("Apply strategies - PP: create '4.1' Tab.")
    df_PPZ=[]
    for c in df:
        if df[c]["Nr."].startswith("PP"):
            df_PPZ.append(df[c])
            
    return df_PPZ

# %%
def filter_out_PPZ_PZ(df):
    print("Apply strategies - PP: create '4.1' Tab.")
    df_PPZ = [df[c] for c in df if df[c]["Nr."].startswith("PP")]
    return df_PPZ

# %%
def transform_df_PPZ(df,D_PSE):
    print("Apply strategies - PP: transform '4.1' Tab.")
    for c in df:
        c['Träger']=[]
        code_list=[ v for k, v in c.items() if k.startswith('Träger ')]
        n_bearbeitet_list=[ v for k, v in c.items() if k.startswith('n ')]
        for i in range(len(code_list)):
            if not math.isnan(n_bearbeitet_list[i]):
                c['Träger'].append({
                    'code':code_list[i],
                    'n_bearbeitet':n_bearbeitet_list[i],
                    'n':1
                })
        for a in D_PSE:
            for exc in a['exchanges']:
                for t in c['Träger']:
                    if exc['type']=='technosphere' and exc['code'] == t['code']:
                        t['n']=-exc['amount']
        entries_to_remove=[ k for k, v in c.items() if (k.startswith('Träger ') or k.startswith('n '))]
        for k in entries_to_remove:
            c.pop(k, None)
        
    df_xPZ_v2=[]
    for PZ in df:
        PZ['ÖW']=[]
        if not any(d['Nr.'] == PZ['Nr.'] for d in df_xPZ_v2):
            df_xPZ_v2.append(PZ)
    for PZ1 in df:
        for PZ2 in df_xPZ_v2:
            if PZ1['Nr.']==PZ2['Nr.'] and PZ1['ÖK-Wert']!=0:
                PZ2['ÖW'].append({
                    'Nr.':PZ1['Ökologie-kriterium'],
                    'amount':PZ1['ÖK-Wert']
                })
    for PZ2 in df_xPZ_v2:
        del PZ2['Ökologie-kriterium']
        del PZ2['ÖK-Wert']
    
    return df_xPZ_v2

# %%
def create_AF(df,allocation_key):
    print("Apply strategies - PP: create AF")
    if allocation_key=='pcs.':
        for PZ in df:
            for PZT in PZ['Träger']:
                PZT['af'] = PZT['n']/sum(item['n_bearbeitet'] for item in PZ['Träger'])
                
    return df

# %%
def add_AF_to_A(df_PPZ, D_PSE):
    print("Apply strategies - PP: add AF to '4.1' Tab.")
    for PSE in D_PSE:
        for PZ in df_PPZ:
            for PZT in PZ['Träger']:
                if PZT['code']==PSE['code']:
                    PSE['exchanges'].append({
                        "name":PZ['Prozess-schritt'],
                        "reference product":PZ['Prozess-schritt'],
                        "unit":"exc.",
                        "code":PZ['Nr.'],
                        "type":"technosphere",
                        "amount":-PZT['af']
                    })
                    
    return D_PSE

# %% [markdown]
# ## lci_PP

# %%
def write_PP_lci(df_PPZ,D_PSE,df_ÖK):
    print("Apply strategies - PP: write lci_PP")
    for PPZ in df_PPZ:
        activity = {
            "name":PPZ['Prozess-schritt'],
            "reference product":PPZ['Prozess-schritt'],
            "unit":"exc.",
            "code":PPZ['Nr.'],
            "exchanges":[{
                "name":PPZ['Prozess-schritt'],
                "reference product":PPZ['Prozess-schritt'],
                "unit":"exc.",
                "code":PPZ['Nr.'],
                "type":"production",
                "amount":1
            }]
        }
        for öw in PPZ['ÖW']:
            activity['exchanges'].append({
                "code":öw['Nr.'],
                "type":"biosphere",
                "amount":-öw['amount']
            })
        D_PSE_v2.append(activity)

    for act in D_PSE:
        for exc in act['exchanges']:
            for ök in df_ÖK:
                if exc['code'] == ök['Nr.']:
                    exc['name']=ök['Kriterium']
                    exc['reference product']=ök['Kriterium']
                    exc['unit']=ök['Einheit']
                    if ök['Generisches Ökologiekriterium'].startswith("Emissionen"):
                        exc['amount']=exc['amount']*(-1)

    return D_PSE

# %% [markdown]
# # main.ipynb simulator

# %%
filepath = r"data/231105_LCA_v24_rsc_kf.xlsm"
sheet_names = [
    "1-Produktstruktur", 
    "2-Funktionsstruktur",
    "3-Ökologiekriterien",
    "4-Prozesse",
    "5-MTTFF MTBF",
    "6-Rückführungswahrs.",
    "7a-Transformbez_PF_gew",
    "7b-Transformbez_FP_gew",
    "8-Nutzungsprofile"
]

################################################################

df_PSE_v1 = unzip_dict(read_excel_file(filepath=filepath, sheet_names=sheet_names)[0]) #<--
df_PSE_v2 = add_träger_column(df=df_PSE_v1)
D_PSE_v1 = transform_excel_sheet_to_matrix_old(df=df_PSE_v2)
D_PSE_v2 = sort_column_by_level(matrix=D_PSE_v1)

df_PZ_ges = read_excel_file(filepath=filepath, sheet_names=sheet_names)[3] #<--
df_PPZ_v1 = filter_out_PPZ_PZ_old(df=df_PZ_ges)
df_PPZ_v2 = transform_df_PPZ(df=df_PPZ_v1,D_PSE=D_PSE_v2) 
df_PPZ_v3 = create_AF(df=df_PPZ_v2,allocation_key='pcs.') #<--

D_PSE_v3 = add_AF_to_A(df_PPZ=df_PPZ_v3, D_PSE=D_PSE_v2)

df_ÖK_v1 = unzip_dict(read_excel_file(filepath=filepath, sheet_names=sheet_names)[2])

lci_PP = write_PP_lci(df_PPZ=df_PPZ_v3, D_PSE=D_PSE_v2, df_ÖK=df_ÖK_v1)
# Out:
# Apply strategies: read excel-file ...
# Apply strategies - PP: add täger-column ...
# Apply strategies - PP: transform excel-sheet to D_PSE matrix ...
# Apply strategies - PP: sort matrix-column by level (descending) ...
# Apply strategies: read excel-file ...
# Apply strategies - PP: create '4.1' Tab.
# Apply strategies - PP: transform '4.1' Tab.
# Apply strategies - PP: create AF
# Apply strategies - PP: add AF to '4.1' Tab.
# Apply strategies: read excel-file ...
# Apply strategies - PP: write lci_PP

# %%
lci_PP
# Out:
# [{'name': 'Stanzmaschine',
#   'reference product': 'Stanzmaschine',
#   'unit': 'pcs.',
#   'code': 'M201830',
#   'level': 0.0,
#   'exchanges': [{'name': 'Stanzmaschine',
#     'reference product': 'Stanzmaschine',
#     'unit': 'pcs.',
#     'code': 'M201830',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Grundgestell',
#     'reference product': 'Grundgestell',
#     'unit': 'pcs.',
#     'code': 'M215720',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Handlingsystem',
#     'reference product': 'Handlingsystem',
#     'unit': 'pcs.',
#     'code': 'M216421',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Antriebssystem',
#     'reference product': 'Antriebssystem',
#     'unit': 'pcs.',
#     'code': 'M217221',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Werkzeugwechselsystem',
#     'reference product': 'Werkzeugwechselsystem',
#     'unit': 'pcs.',
#     'code': 'M218130',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Werkzeugsystem',
#     'reference product': 'Werkzeugsystem',
#     'unit': 'pcs.',
#     'code': 'M219221',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1002',
#     'type': 'technosphere',
#     'amount': -1.0}]},
#  {'name': 'Grundgestell',
#   'reference product': 'Grundgestell',
#   'unit': 'pcs.',
#   'code': 'M215720',
#   'level': 1.0,
#   'exchanges': [{'name': 'Grundgestell',
#     'reference product': 'Grundgestell',
#     'unit': 'pcs.',
#     'code': 'M215720',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Querträger',
#     'reference product': 'Querträger',
#     'unit': 'pcs.',
#     'code': 'M225220',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Obertisch',
#     'reference product': 'Obertisch',
#     'unit': 'pcs.',
#     'code': 'M225310',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Untertisch',
#     'reference product': 'Untertisch',
#     'unit': 'pcs.',
#     'code': 'M225400',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Abtriebsstrang',
#     'reference product': 'Abtriebsstrang',
#     'unit': 'pcs.',
#     'code': 'M225620',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1001',
#     'type': 'technosphere',
#     'amount': -0.16666666666666666}]},
#  {'name': 'Handlingsystem',
#   'reference product': 'Handlingsystem',
#   'unit': 'pcs.',
#   'code': 'M216421',
#   'level': 1.0,
#   'exchanges': [{'name': 'Handlingsystem',
#     'reference product': 'Handlingsystem',
#     'unit': 'pcs.',
#     'code': 'M216421',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Lineareinheit',
#     'reference product': 'Lineareinheit',
#     'unit': 'pcs.',
#     'code': 'M226220',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Förderbandeinheit',
#     'reference product': 'Förderbandeinheit',
#     'unit': 'pcs.',
#     'code': 'M226311',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1018',
#     'type': 'technosphere',
#     'amount': -1.0}]},
#  {'name': 'Antriebssystem',
#   'reference product': 'Antriebssystem',
#   'unit': 'pcs.',
#   'code': 'M217221',
#   'level': 1.0,
#   'exchanges': [{'name': 'Antriebssystem',
#     'reference product': 'Antriebssystem',
#     'unit': 'pcs.',
#     'code': 'M217221',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Werkzeugantrieb',
#     'reference product': 'Werkzeugantrieb',
#     'unit': 'pcs.',
#     'code': 'M227122',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Linearachse',
#     'reference product': 'Linearachse',
#     'unit': 'pcs.',
#     'code': 'M227200',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Drehtisch',
#     'reference product': 'Drehtisch',
#     'unit': 'pcs.',
#     'code': 'M227421',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1020',
#     'type': 'technosphere',
#     'amount': -0.2}]},
#  {'name': 'Werkzeugwechselsystem',
#   'reference product': 'Werkzeugwechselsystem',
#   'unit': 'pcs.',
#   'code': 'M218130',
#   'level': 1.0,
#   'exchanges': [{'name': 'Werkzeugwechselsystem',
#     'reference product': 'Werkzeugwechselsystem',
#     'unit': 'pcs.',
#     'code': 'M218130',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Werkzeugwechselbahnhof',
#     'reference product': 'Werkzeugwechselbahnhof',
#     'unit': 'pcs.',
#     'code': 'M228372',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Werkzeugwechselkonsole',
#     'reference product': 'Werkzeugwechselkonsole',
#     'unit': 'pcs.',
#     'code': 'M228467',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Werkzeugwechselwagen',
#     'reference product': 'Werkzeugwechselwagen',
#     'unit': 'pcs.',
#     'code': 'M228633',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1024',
#     'type': 'technosphere',
#     'amount': -0.017857142857142856}]},
#  {'name': 'Werkzeugsystem',
#   'reference product': 'Werkzeugsystem',
#   'unit': 'pcs.',
#   'code': 'M219221',
#   'level': 1.0,
#   'exchanges': [{'name': 'Werkzeugsystem',
#     'reference product': 'Werkzeugsystem',
#     'unit': 'pcs.',
#     'code': 'M219221',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Oberwerkzeug',
#     'reference product': 'Oberwerkzeug',
#     'unit': 'pcs.',
#     'code': 'M229111',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Unterwerkzeug',
#     'reference product': 'Unterwerkzeug',
#     'unit': 'pcs.',
#     'code': 'M229231',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Stanzeinheit',
#     'reference product': 'Stanzeinheit',
#     'unit': 'pcs.',
#     'code': 'M229330',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1028',
#     'type': 'technosphere',
#     'amount': -0.16666666666666666}]},
#  {'name': 'Querträger',
#   'reference product': 'Querträger',
#   'unit': 'pcs.',
#   'code': 'M225220',
#   'level': 2.0,
#   'exchanges': [{'name': 'Querträger',
#     'reference product': 'Querträger',
#     'unit': 'pcs.',
#     'code': 'M225220',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1001',
#     'type': 'technosphere',
#     'amount': -0.16666666666666666}]},
#  {'name': 'Obertisch',
#   'reference product': 'Obertisch',
#   'unit': 'pcs.',
#   'code': 'M225310',
#   'level': 2.0,
#   'exchanges': [{'name': 'Obertisch',
#     'reference product': 'Obertisch',
#     'unit': 'pcs.',
#     'code': 'M225310',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Werkzeugverriegelung',
#     'reference product': 'Werkzeugverriegelung',
#     'unit': 'pcs.',
#     'code': 'M231301',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Medienandockung',
#     'reference product': 'Medienandockung',
#     'unit': 'pcs.',
#     'code': 'M231400',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1003',
#     'type': 'technosphere',
#     'amount': -0.018518518518518517}]},
#  {'name': 'Untertisch',
#   'reference product': 'Untertisch',
#   'unit': 'pcs.',
#   'code': 'M225400',
#   'level': 2.0,
#   'exchanges': [{'name': 'Untertisch',
#     'reference product': 'Untertisch',
#     'unit': 'pcs.',
#     'code': 'M225400',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Werkzeugverriegelung',
#     'reference product': 'Werkzeugverriegelung',
#     'unit': 'pcs.',
#     'code': 'M232140',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Aushebeleisten',
#     'reference product': 'Aushebeleisten',
#     'unit': 'pcs.',
#     'code': 'M232310',
#     'type': 'technosphere',
#     'amount': -4.0},
#    {'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1012',
#     'type': 'technosphere',
#     'amount': -0.125}]},
#  {'name': 'Abtriebsstrang',
#   'reference product': 'Abtriebsstrang',
#   'unit': 'pcs.',
#   'code': 'M225620',
#   'level': 2.0,
#   'exchanges': [{'name': 'Abtriebsstrang',
#     'reference product': 'Abtriebsstrang',
#     'unit': 'pcs.',
#     'code': 'M225620',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Führungsbuchsen',
#     'reference product': 'Führungsbuchsen',
#     'unit': 'pcs.',
#     'code': 'M233330',
#     'type': 'technosphere',
#     'amount': -3.0},
#    {'name': 'Führungssäulen',
#     'reference product': 'Führungssäulen',
#     'unit': 'pcs.',
#     'code': 'M233410',
#     'type': 'technosphere',
#     'amount': -3.0},
#    {'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1015',
#     'type': 'technosphere',
#     'amount': -0.125}]},
#  {'name': 'Lineareinheit',
#   'reference product': 'Lineareinheit',
#   'unit': 'pcs.',
#   'code': 'M226220',
#   'level': 2.0,
#   'exchanges': [{'name': 'Lineareinheit',
#     'reference product': 'Lineareinheit',
#     'unit': 'pcs.',
#     'code': 'M226220',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1019',
#     'type': 'technosphere',
#     'amount': -0.05263157894736842}]},
#  {'name': 'Förderbandeinheit',
#   'reference product': 'Förderbandeinheit',
#   'unit': 'pcs.',
#   'code': 'M226311',
#   'level': 2.0,
#   'exchanges': [{'name': 'Förderbandeinheit',
#     'reference product': 'Förderbandeinheit',
#     'unit': 'pcs.',
#     'code': 'M226311',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1019',
#     'type': 'technosphere',
#     'amount': -0.05263157894736842}]},
#  {'name': 'Werkzeugantrieb',
#   'reference product': 'Werkzeugantrieb',
#   'unit': 'pcs.',
#   'code': 'M227122',
#   'level': 2.0,
#   'exchanges': [{'name': 'Werkzeugantrieb',
#     'reference product': 'Werkzeugantrieb',
#     'unit': 'pcs.',
#     'code': 'M227122',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1021',
#     'type': 'technosphere',
#     'amount': -0.2}]},
#  {'name': 'Linearachse',
#   'reference product': 'Linearachse',
#   'unit': 'pcs.',
#   'code': 'M227200',
#   'level': 2.0,
#   'exchanges': [{'name': 'Linearachse',
#     'reference product': 'Linearachse',
#     'unit': 'pcs.',
#     'code': 'M227200',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1022',
#     'type': 'technosphere',
#     'amount': -0.25}]},
#  {'name': 'Drehtisch',
#   'reference product': 'Drehtisch',
#   'unit': 'pcs.',
#   'code': 'M227421',
#   'level': 2.0,
#   'exchanges': [{'name': 'Drehtisch',
#     'reference product': 'Drehtisch',
#     'unit': 'pcs.',
#     'code': 'M227421',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1023',
#     'type': 'technosphere',
#     'amount': -0.011764705882352941}]},
#  {'name': 'Werkzeugwechselbahnhof',
#   'reference product': 'Werkzeugwechselbahnhof',
#   'unit': 'pcs.',
#   'code': 'M228372',
#   'level': 2.0,
#   'exchanges': [{'name': 'Werkzeugwechselbahnhof',
#     'reference product': 'Werkzeugwechselbahnhof',
#     'unit': 'pcs.',
#     'code': 'M228372',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1025',
#     'type': 'technosphere',
#     'amount': -0.02127659574468085}]},
#  {'name': 'Werkzeugwechselkonsole',
#   'reference product': 'Werkzeugwechselkonsole',
#   'unit': 'pcs.',
#   'code': 'M228467',
#   'level': 2.0,
#   'exchanges': [{'name': 'Werkzeugwechselkonsole',
#     'reference product': 'Werkzeugwechselkonsole',
#     'unit': 'pcs.',
#     'code': 'M228467',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1026',
#     'type': 'technosphere',
#     'amount': -0.16666666666666666}]},
#  {'name': 'Werkzeugwechselwagen',
#   'reference product': 'Werkzeugwechselwagen',
#   'unit': 'pcs.',
#   'code': 'M228633',
#   'level': 2.0,
#   'exchanges': [{'name': 'Werkzeugwechselwagen',
#     'reference product': 'Werkzeugwechselwagen',
#     'unit': 'pcs.',
#     'code': 'M228633',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1027',
#     'type': 'technosphere',
#     'amount': -0.022222222222222223}]},
#  {'name': 'Oberwerkzeug',
#   'reference product': 'Oberwerkzeug',
#   'unit': 'pcs.',
#   'code': 'M229111',
#   'level': 2.0,
#   'exchanges': [{'name': 'Oberwerkzeug',
#     'reference product': 'Oberwerkzeug',
#     'unit': 'pcs.',
#     'code': 'M229111',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1029',
#     'type': 'technosphere',
#     'amount': -0.045454545454545456}]},
#  {'name': 'Unterwerkzeug',
#   'reference product': 'Unterwerkzeug',
#   'unit': 'pcs.',
#   'code': 'M229231',
#   'level': 2.0,
#   'exchanges': [{'name': 'Unterwerkzeug',
#     'reference product': 'Unterwerkzeug',
#     'unit': 'pcs.',
#     'code': 'M229231',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1029',
#     'type': 'technosphere',
#     'amount': -0.045454545454545456}]},
#  {'name': 'Stanzeinheit',
#   'reference product': 'Stanzeinheit',
#   'unit': 'pcs.',
#   'code': 'M229330',
#   'level': 2.0,
#   'exchanges': [{'name': 'Stanzeinheit',
#     'reference product': 'Stanzeinheit',
#     'unit': 'pcs.',
#     'code': 'M229330',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1029',
#     'type': 'technosphere',
#     'amount': -0.045454545454545456}]},
#  {'name': 'Werkzeugverriegelung',
#   'reference product': 'Werkzeugverriegelung',
#   'unit': 'pcs.',
#   'code': 'M231301',
#   'level': 3.0,
#   'exchanges': [{'name': 'Werkzeugverriegelung',
#     'reference product': 'Werkzeugverriegelung',
#     'unit': 'pcs.',
#     'code': 'M231301',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Kolben',
#     'reference product': 'Kolben',
#     'unit': 'pcs.',
#     'code': 'M244180',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Faltenbalg',
#     'reference product': 'Faltenbalg',
#     'unit': 'pcs.',
#     'code': 'M244241',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Dämpfung',
#     'reference product': 'Dämpfung',
#     'unit': 'pcs.',
#     'code': 'M244380',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Gegenlager',
#     'reference product': 'Gegenlager',
#     'unit': 'pcs.',
#     'code': 'M244461',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Anschlusskabel',
#     'reference product': 'Anschlusskabel',
#     'unit': 'pcs.',
#     'code': 'M244553',
#     'type': 'technosphere',
#     'amount': -5.0},
#    {'name': 'Befestigung',
#     'reference product': 'Befestigung',
#     'unit': 'pcs.',
#     'code': 'M244630',
#     'type': 'technosphere',
#     'amount': -1.0},
#    {'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1004',
#     'type': 'technosphere',
#     'amount': -0.25}]},
#  {'name': 'Medienandockung',
#   'reference product': 'Medienandockung',
#   'unit': 'pcs.',
#   'code': 'M231400',
#   'level': 3.0,
#   'exchanges': [{'name': 'Medienandockung',
#     'reference product': 'Medienandockung',
#     'unit': 'pcs.',
#     'code': 'M231400',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1011',
#     'type': 'technosphere',
#     'amount': -0.02127659574468085}]},
#  {'name': 'Werkzeugverriegelung',
#   'reference product': 'Werkzeugverriegelung',
#   'unit': 'pcs.',
#   'code': 'M232140',
#   'level': 3.0,
#   'exchanges': [{'name': 'Werkzeugverriegelung',
#     'reference product': 'Werkzeugverriegelung',
#     'unit': 'pcs.',
#     'code': 'M232140',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1013',
#     'type': 'technosphere',
#     'amount': -1.0}]},
#  {'name': 'Aushebeleisten',
#   'reference product': 'Aushebeleisten',
#   'unit': 'pcs.',
#   'code': 'M232310',
#   'level': 3.0,
#   'exchanges': [{'name': 'Aushebeleisten',
#     'reference product': 'Aushebeleisten',
#     'unit': 'pcs.',
#     'code': 'M232310',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1014',
#     'type': 'technosphere',
#     'amount': -0.08888888888888889}]},
#  {'name': 'Führungsbuchsen',
#   'reference product': 'Führungsbuchsen',
#   'unit': 'pcs.',
#   'code': 'M233330',
#   'level': 3.0,
#   'exchanges': [{'name': 'Führungsbuchsen',
#     'reference product': 'Führungsbuchsen',
#     'unit': 'pcs.',
#     'code': 'M233330',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1016',
#     'type': 'technosphere',
#     'amount': -0.42857142857142855}]},
#  {'name': 'Führungssäulen',
#   'reference product': 'Führungssäulen',
#   'unit': 'pcs.',
#   'code': 'M233410',
#   'level': 3.0,
#   'exchanges': [{'name': 'Führungssäulen',
#     'reference product': 'Führungssäulen',
#     'unit': 'pcs.',
#     'code': 'M233410',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1017',
#     'type': 'technosphere',
#     'amount': -0.6}]},
#  {'name': 'Kolben',
#   'reference product': 'Kolben',
#   'unit': 'pcs.',
#   'code': 'M244180',
#   'level': 4.0,
#   'exchanges': [{'name': 'Kolben',
#     'reference product': 'Kolben',
#     'unit': 'pcs.',
#     'code': 'M244180',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1005',
#     'type': 'technosphere',
#     'amount': -0.14285714285714285}]},
#  {'name': 'Faltenbalg',
#   'reference product': 'Faltenbalg',
#   'unit': 'pcs.',
#   'code': 'M244241',
#   'level': 4.0,
#   'exchanges': [{'name': 'Faltenbalg',
#     'reference product': 'Faltenbalg',
#     'unit': 'pcs.',
#     'code': 'M244241',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1006',
#     'type': 'technosphere',
#     'amount': -0.1111111111111111}]},
#  {'name': 'Dämpfung',
#   'reference product': 'Dämpfung',
#   'unit': 'pcs.',
#   'code': 'M244380',
#   'level': 4.0,
#   'exchanges': [{'name': 'Dämpfung',
#     'reference product': 'Dämpfung',
#     'unit': 'pcs.',
#     'code': 'M244380',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1007',
#     'type': 'technosphere',
#     'amount': -1.0}]},
#  {'name': 'Gegenlager',
#   'reference product': 'Gegenlager',
#   'unit': 'pcs.',
#   'code': 'M244461',
#   'level': 4.0,
#   'exchanges': [{'name': 'Gegenlager',
#     'reference product': 'Gegenlager',
#     'unit': 'pcs.',
#     'code': 'M244461',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1008',
#     'type': 'technosphere',
#     'amount': -0.07142857142857142}]},
#  {'name': 'Anschlusskabel',
#   'reference product': 'Anschlusskabel',
#   'unit': 'pcs.',
#   'code': 'M244553',
#   'level': 4.0,
#   'exchanges': [{'name': 'Anschlusskabel',
#     'reference product': 'Anschlusskabel',
#     'unit': 'pcs.',
#     'code': 'M244553',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1009',
#     'type': 'technosphere',
#     'amount': -1.0}]},
#  {'name': 'Befestigung',
#   'reference product': 'Befestigung',
#   'unit': 'pcs.',
#   'code': 'M244630',
#   'level': 4.0,
#   'exchanges': [{'name': 'Befestigung',
#     'reference product': 'Befestigung',
#     'unit': 'pcs.',
#     'code': 'M244630',
#     'type': 'production',
#     'amount': 1},
#    {'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1010',
#     'type': 'technosphere',
#     'amount': -0.3333333333333333}]},
#  {'name': nan,
#   'reference product': nan,
#   'unit': 'pcs.',
#   'code': 'R137137',
#   'level': nan,
#   'exchanges': [{'name': nan,
#     'reference product': nan,
#     'unit': 'pcs.',
#     'code': 'R137137',
#     'type': 'production',
#     'amount': 1}]},
#  {'name': 'Fügen - Schweißen',
#   'reference product': 'Fügen - Schweißen',
#   'unit': 'exc.',
#   'code': 'PP1002',
#   'exchanges': [{'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1002',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -34.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.3,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.12,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Stanzen',
#   'reference product': 'Stanzen',
#   'unit': 'exc.',
#   'code': 'PP1001',
#   'exchanges': [{'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1001',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -26.7,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.35,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Umbugen',
#   'reference product': 'Umbugen',
#   'unit': 'exc.',
#   'code': 'PP1003',
#   'exchanges': [{'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1003',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -23.5,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 1.2,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.31,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fräsen',
#   'reference product': 'Fräsen',
#   'unit': 'exc.',
#   'code': 'PP1004',
#   'exchanges': [{'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1004',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -22.0,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -1.12,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Entgraten',
#   'reference product': 'Entgraten',
#   'unit': 'exc.',
#   'code': 'PP1005',
#   'exchanges': [{'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1005',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 6.0,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.02,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -45.0,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.3,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.2,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Stanzen',
#   'reference product': 'Stanzen',
#   'unit': 'exc.',
#   'code': 'PP1006',
#   'exchanges': [{'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1006',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 3.0,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -15.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.4,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.13,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Reinigen',
#   'reference product': 'Reinigen',
#   'unit': 'exc.',
#   'code': 'PP1007',
#   'exchanges': [{'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1007',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 5.3,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.02,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -30.6,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.6,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.16,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fräsen',
#   'reference product': 'Fräsen',
#   'unit': 'exc.',
#   'code': 'PP1008',
#   'exchanges': [{'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1008',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 5.0,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.02,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -25.0,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.21,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fügen - Schweißen',
#   'reference product': 'Fügen - Schweißen',
#   'unit': 'exc.',
#   'code': 'PP1009',
#   'exchanges': [{'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1009',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 3.1,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.9,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -15.4,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.3,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.18,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Umbugen',
#   'reference product': 'Umbugen',
#   'unit': 'exc.',
#   'code': 'PP1010',
#   'exchanges': [{'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1010',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 3.3,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.06,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -18.7,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.38,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Reinigen',
#   'reference product': 'Reinigen',
#   'unit': 'exc.',
#   'code': 'PP1011',
#   'exchanges': [{'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1011',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 4.0,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.2,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -22.1,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.2,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.25,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Reinigen',
#   'reference product': 'Reinigen',
#   'unit': 'exc.',
#   'code': 'PP1012',
#   'exchanges': [{'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1012',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -98.6,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.2,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.64,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Stanzen',
#   'reference product': 'Stanzen',
#   'unit': 'exc.',
#   'code': 'PP1013',
#   'exchanges': [{'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1013',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 4.2,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -21.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.36,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Reinigen',
#   'reference product': 'Reinigen',
#   'unit': 'exc.',
#   'code': 'PP1014',
#   'exchanges': [{'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1014',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 5.2,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -25.4,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 1.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.29,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Umbugen',
#   'reference product': 'Umbugen',
#   'unit': 'exc.',
#   'code': 'PP1015',
#   'exchanges': [{'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1015',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -10.0,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -1.25,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Reinigen',
#   'reference product': 'Reinigen',
#   'unit': 'exc.',
#   'code': 'PP1016',
#   'exchanges': [{'name': 'Reinigen',
#     'reference product': 'Reinigen',
#     'unit': 'exc.',
#     'code': 'PP1016',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 3.4,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -11.2,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.2,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.43,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fräsen',
#   'reference product': 'Fräsen',
#   'unit': 'exc.',
#   'code': 'PP1017',
#   'exchanges': [{'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1017',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 5.6,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.02,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -16.8,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.4,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Entgraten',
#   'reference product': 'Entgraten',
#   'unit': 'exc.',
#   'code': 'PP1018',
#   'exchanges': [{'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1018',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -10.1,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.23,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fügen - Schweißen',
#   'reference product': 'Fügen - Schweißen',
#   'unit': 'exc.',
#   'code': 'PP1019',
#   'exchanges': [{'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1019',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 11.2,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.8,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.1,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -59.4,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.8,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.87,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Umbugen',
#   'reference product': 'Umbugen',
#   'unit': 'exc.',
#   'code': 'PP1020',
#   'exchanges': [{'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1020',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -21.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.51,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fügen - Schweißen',
#   'reference product': 'Fügen - Schweißen',
#   'unit': 'exc.',
#   'code': 'PP1021',
#   'exchanges': [{'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1021',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 1.2,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK002',
#     'type': 'biosphere',
#     'amount': 0.7,
#     'name': 'CH4',
#     'reference product': 'CH4',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -22.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.21,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Entgraten',
#   'reference product': 'Entgraten',
#   'unit': 'exc.',
#   'code': 'PP1022',
#   'exchanges': [{'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1022',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 2.8,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.08,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -19.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.3,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.14,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Stanzen',
#   'reference product': 'Stanzen',
#   'unit': 'exc.',
#   'code': 'PP1023',
#   'exchanges': [{'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1023',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 4.9,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.02,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -82.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.32,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Entgraten',
#   'reference product': 'Entgraten',
#   'unit': 'exc.',
#   'code': 'PP1024',
#   'exchanges': [{'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1024',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -16.8,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.29,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fräsen',
#   'reference product': 'Fräsen',
#   'unit': 'exc.',
#   'code': 'PP1025',
#   'exchanges': [{'name': 'Fräsen',
#     'reference product': 'Fräsen',
#     'unit': 'exc.',
#     'code': 'PP1025',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 0.9,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -34.1,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.34,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Stanzen',
#   'reference product': 'Stanzen',
#   'unit': 'exc.',
#   'code': 'PP1026',
#   'exchanges': [{'name': 'Stanzen',
#     'reference product': 'Stanzen',
#     'unit': 'exc.',
#     'code': 'PP1026',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 1.2,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -15.2,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.21,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Entgraten',
#   'reference product': 'Entgraten',
#   'unit': 'exc.',
#   'code': 'PP1027',
#   'exchanges': [{'name': 'Entgraten',
#     'reference product': 'Entgraten',
#     'unit': 'exc.',
#     'code': 'PP1027',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 1.5,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.01,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -22.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.1,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -0.3,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Umbugen',
#   'reference product': 'Umbugen',
#   'unit': 'exc.',
#   'code': 'PP1028',
#   'exchanges': [{'name': 'Umbugen',
#     'reference product': 'Umbugen',
#     'unit': 'exc.',
#     'code': 'PP1028',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -15.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -1.54,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]},
#  {'name': 'Fügen - Schweißen',
#   'reference product': 'Fügen - Schweißen',
#   'unit': 'exc.',
#   'code': 'PP1029',
#   'exchanges': [{'name': 'Fügen - Schweißen',
#     'reference product': 'Fügen - Schweißen',
#     'unit': 'exc.',
#     'code': 'PP1029',
#     'type': 'production',
#     'amount': 1},
#    {'code': 'ÖK001',
#     'type': 'biosphere',
#     'amount': 15.3,
#     'name': 'CO2',
#     'reference product': 'CO2',
#     'unit': 'kg'},
#    {'code': 'ÖK003',
#     'type': 'biosphere',
#     'amount': -0.08,
#     'name': 'KSS',
#     'reference product': 'KSS',
#     'unit': 'l'},
#    {'code': 'ÖK004',
#     'type': 'biosphere',
#     'amount': -84.3,
#     'name': 'H2O',
#     'reference product': 'H2O',
#     'unit': 'l'},
#    {'code': 'ÖK005',
#     'type': 'biosphere',
#     'amount': 0.5,
#     'name': 'H2OSchmutz',
#     'reference product': 'H2OSchmutz',
#     'unit': 'l'},
#    {'code': 'ÖK006',
#     'type': 'biosphere',
#     'amount': -2.34,
#     'name': 'Eel',
#     'reference product': 'Eel',
#     'unit': 'kWh'}]}]

# %% [markdown]
# # Functions - old

# %%
def add_träger_column_old(df):
    print("Apply strategies - PP: add Träger-column ...")

    for a in df:
        current_e = int(a["Ebene"]) if not math.isnan(a["Ebene"]) else 0
        current_nr = a["Nr."]
        
        e_values = [current_nr if current_e >= i else "-" for i in range(5)]
        upper_e = e_values[current_e - 1] if current_e > 0 else "-"

        a["Träger"] = upper_e

    return df

# %%
def transform_excel_sheet_to_matrix_old(df):
    print("Apply strategies - PP: transform excel-sheet to D_PSE matrix ...")

    df_new = [{
        "name": PSE['Bezeichnung'],
        "reference product": PSE['Bezeichnung'],
        "unit": "pcs.",
        "code": PSE['Nr.'],
        "level": PSE['Ebene'],
        "exchanges": [{
            "name": PSE['Bezeichnung'],
            "reference product": PSE['Bezeichnung'],
            "unit": "pcs.",
            "code": PSE['Nr.'],
            "type": "production",
            "amount": 1
        }]}
        for PSE in df]

    for a2 in df:
        for a_count, PSE in enumerate(df_new):
            if a2['Träger'] == PSE["code"]:
                PSE["exchanges"].append({
                    "name": a2['Bezeichnung'],
                    "reference product": a2['Bezeichnung'],
                    "unit": "pcs.",
                    "code": a2['Nr.'],
                    "type": "technosphere",
                    "amount": -a2['Menge']
                })

    return df_new

# %% [markdown]
# # Spielwiese

# %%
D_PSE_v2

# %%
df_PPZ_v2=[]
for PPZ in df_PPZ_v1:
    PPZ['ÖW']=[]
    if not any(d['Nr.'] == PPZ['Nr.'] for d in df_PPZ_v2):
        df_PPZ_v2.append(PPZ)
        
for PPZ1 in df_PPZ_v1:
    for PPZ2 in df_PPZ_v2:
        if PPZ1['Nr.']==PPZ2['Nr.'] and PPZ1['ÖK-Wert']!=0:
            PPZ2['ÖW'].append({'Nr.':PPZ1['Ökologie-kriterium'],
                               'Amount':PPZ1['ÖK-Wert']})
for PPZ2 in df_PPZ_v2:
    del PPZ2['Ökologie-kriterium']
    del PPZ2['ÖK-Wert']

        
df_PPZ_v2

# %%
for c in df_PPZ_v1:
    c['Träger']=[ v for k, v in c.items() if k.startswith('Träger ')]
    c['n_bearbeitet']=[ v for k, v in c.items() if k.startswith('n ')]
    c['n']=[]
    for a in D_PSE_v2 :
        for exc in a['exchanges']:
            for t in c['Träger']:
                if exc['type']=='technosphere' and exc['code'] == t:
                    c['n'].append(-exc['amount'])
                else:
                    
    
    
    entries_to_remove=[ k for k, v in c.items() if (k.startswith('Träger ') or k.startswith('n '))]
    for k in entries_to_remove:
        c.pop(k, None)

# %%
df_PPZ=[]
for c in df:
    if df[c]["Nr."].startswith("PP"):
        df_PPZ.append(df[c])
df_PPZ

# %%
df_D_PSE_v3 = []

for a in df_D_PSE_v2:
    df_D_PSE_v3.append({
        "name":df_D_PSE_v2[a]['Bezeichnung'],
        "reference product":df_D_PSE_v2[a]['Bezeichnung'],
        "unit":"pcs.",
        "code":df_D_PSE_v2[a]['Nr.'],
        "level":df_D_PSE_v2[a]['Ebene'],
        "exchanges":[{
            "name":df_D_PSE_v2[a]['Bezeichnung'],
            "reference product":df_D_PSE_v2[a]['Bezeichnung'],
            "unit":"pcs.",
            "type":"production",
            "amount":1
        }]
    })
    for a2 in df_D_PSE_v2:
        if df_D_PSE_v2[a2]['Träger']==df_D_PSE_v3[a]["code"]:
            df_D_PSE_v3[a]["exchanges"].append({
                "name":df_D_PSE_v2[a2]['Bezeichnung'],
                "reference product":df_D_PSE_v2[a2]['Bezeichnung'],
                "unit":"pcs.",
                "type":"technosphere",
                "amount":-df_D_PSE_v2[a2]['Menge']
            })
        
    
    

    
    
df_D_PSE_v3
